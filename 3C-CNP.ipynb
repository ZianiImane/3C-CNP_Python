# %% [markdown]
# Used libraries:

# %%
import graph_tool.all as gt
import random
import multiprocessing
import time

# %% [markdown]
# Global variables:
#
# - file: contains the file's path.
#
# - L: maximum size of a component.

# %%
file = "karate.gml"
L = 5

# %% [markdown]
# Defining functions:
#
# - createGraph(file): takes the file's path as an input and returns the graph as a Graph tool object.
#
# - drawGraph(file): takes a graph tool graph and draw it on screen.
#
# - calculateMIS(graph): takes a graph as an output, calculates its maximal independent set then returns a list of boolean: 1 if a vertex is part of the MIS and 0 otherwise. The length of the list is the size of the graph.

# %%
def createGraph(file):
    return gt.load_graph(file)

def drawGraph(Graph):
    gt.graph_draw(Graph, vertex_text=Graph.vertex_index, vertex_font_size=18, output=None)
    
def calculateMIS(Graph):
    return gt.max_independent_vertex_set(Graph)

def componentSizeFunc(MIS, testGraph, remvseq):
    rndmV = random.choice(remvseq)
    MIS[rndmV] = True
    component = gt.label_out_component(testGraph, testGraph.vertex(rndmV))
    componentSize = list(component.a).count(1)
    MIS[rndmV] = False        
    remvseq.remove(rndmV)  
    return componentSize, rndmV

# %% [markdown]
# Main program:

# %%
#Create graph
mainGraph = createGraph(file)
#print its descriptions
print(mainGraph)
#draw it
drawGraph(mainGraph)
# Out:
# <Graph object, undirected, with 34 vertices and 78 edges at 0x7f5b679d5690>

# %% [markdown]
# Now we calculate the MIS using the predefined graph tool function then show it on the graph.
# To extract the MIS vertices, we use a filter.

# %%
#Calculate MIS
MIS = calculateMIS(mainGraph)
#Show MIS on the main Graph (nodes in yellow)
gt.graph_draw(mainGraph,vertex_text = mainGraph.vertex_index, vertex_fill_color = MIS, output = None)
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x7f5b679d5690, at 0x7f5b67a0e9d0>

# %% [markdown]
# We create a deep copy from the main graph, test graph, that contains the MIS only and use it to test components size when adding random vertices.

# %%
#We make a deep copy of the mainGraph
testGraph = gt.Graph(mainGraph)
#We filter out the nodes that remain in the MIS.
testGraph.set_vertex_filter(MIS, inverted = True)
#We create a sequence that contains remvseq = all_vertices - MIS.
remvseq = list(testGraph.get_vertices())
#we change the testGraph so that it contains the MIS
testGraph.set_vertex_filter(MIS, inverted = False)
#We show the testGraph
drawGraph(testGraph)

# %%
#We make a deep copy of remvseq
tempvseq = remvseq.copy()

testGraph1 = gt.Graph(mainGraph)
testGraph2 = gt.Graph(mainGraph)
testGraph2 = gt.Graph(mainGraph)

# %%
while True:
    minSize = -1
    minV = -1
    
    MIS1 = MIS.copy()
    MIS2 = MIS.copy()
    MIS3 = MIS.copy()

    
    testGraph1.set_vertex_filter(MIS1, inverted = False)
    testGraph2.set_vertex_filter(MIS2, inverted = False)    
    testGraph2.set_vertex_filter(MIS3, inverted = False)


    while len(remvseq) > 0:
        componentSize, rndmV = componentSizeFunc(MIS, testGraph, remvseq) 
        print("componentSize: ",componentSize)
        if componentSize <= L:
            if minSize == -1 or minSize >= componentSize or minV == -1:
                minSize = componentSize
                minV = rndmV

    #print("min size", minSize, " min vertex:", minV)
    
    if minV in tempvseq:
        MIS[minV] = True
        tempvseq.remove(minV)
        remvseq = tempvseq.copy()
    else:
        break
        
drawGraph(testGraph)
# Out:
# componentSize:  2
# minSize:  2
# minV:  6
# componentSize:  3
# minSize:  2
# minV:  6
# componentSize:  4
# minSize:  2
# minV:  6
# componentSize:  3
# minSize:  2
# minV:  6
# componentSize:  2
# minSize:  2
# minV:  30
# componentSize:  2
# minSize:  2
# minV:  29
# componentSize:  10
# minSize:  2
# minV:  29
# componentSize:  3
# minSize:  2
# minV:  29
# componentSize:  7
# minSize:  2
# minV:  29
# componentSize:  6
# minSize:  2
# minV:  29
# componentSize:  2
# minSize:  2
# minV:  4
# componentSize:  3
# minSize:  2
# minV:  4
# componentSize:  7
# minSize:  2
# minV:  4
# componentSize:  13
# minSize:  2
# minV:  4
# componentSize:  2
# minSize:  2
# minV:  29
# componentSize:  6
# minSize:  2
# minV:  29
# componentSize:  7
# minSize:  2
# minV:  29
# componentSize:  13
# minSize:  2
# minV:  29
# componentSize:  4
# minSize:  2
# minV:  29
# componentSize:  4
# minSize:  2
# minV:  29
# componentSize:  3
# minSize:  2
# minV:  29
# componentSize:  11
# minSize:  2
# minV:  29
# componentSize:  3
# minSize:  2
# minV:  29
# componentSize:  2
# minSize:  2
# minV:  30
# componentSize:  7
# minSize:  2
# minV:  30
# componentSize:  4
# minSize:  2
# minV:  30
# componentSize:  3
# minSize:  2
# minV:  30
# componentSize:  3
# minSize:  3
# minV:  23
# componentSize:  2
# minSize:  2
# minV:  29
# componentSize:  4
# minSize:  2
# minV:  29
# componentSize:  8
# minSize:  2
# minV:  29
# componentSize:  3
# minSize:  2
# minV:  29
# componentSize:  3
# minSize:  2
# minV:  29
# componentSize:  4
# minSize:  2
# minV:  29
# componentSize:  4
# minSize:  2
# minV:  29
# componentSize:  8
# minSize:  2
# minV:  29
# componentSize:  8
# minSize:  2
# minV:  29
# componentSize:  12
# minSize:  2
# minV:  29
# componentSize:  14
# minSize:  2
# minV:  29
# componentSize:  8
# minSize:  -1
# minV:  -1
# componentSize:  5
# minSize:  5
# minV:  23
# componentSize:  3
# minSize:  3
# minV:  31
# componentSize:  4
# minSize:  3
# minV:  31
# componentSize:  8
# minSize:  3
# minV:  31
# componentSize:  10
# minSize:  3
# minV:  31
# componentSize:  3
# minSize:  3
# minV:  24
# componentSize:  15
# minSize:  3
# minV:  24
# componentSize:  12
# minSize:  3
# minV:  24
# componentSize:  4
# minSize:  3
# minV:  24
# componentSize:  4
# minSize:  3
# minV:  24
# componentSize:  10
# minSize:  -1
# minV:  -1
# componentSize:  4
# minSize:  4
# minV:  3
# componentSize:  8
# minSize:  4
# minV:  3
# componentSize:  12
# minSize:  4
# minV:  3
# componentSize:  5
# minSize:  4
# minV:  3
# componentSize:  10
# minSize:  4
# minV:  3
# componentSize:  4
# minSize:  4
# minV:  5
# componentSize:  17
# minSize:  4
# minV:  5
# componentSize:  4
# minSize:  4
# minV:  6
# componentSize:  6
# minSize:  4
# minV:  6
# componentSize:  5
# minSize:  5
# minV:  31
# componentSize:  17
# minSize:  5
# minV:  31
# componentSize:  10
# minSize:  5
# minV:  31
# componentSize:  5
# minSize:  5
# minV:  5
# componentSize:  4
# minSize:  4
# minV:  3
# componentSize:  10
# minSize:  4
# minV:  3
# componentSize:  6
# minSize:  4
# minV:  3
# componentSize:  14
# minSize:  4
# minV:  3
# componentSize:  8
# minSize:  4
# minV:  3
# componentSize:  10
# minSize:  -1
# minV:  -1
# componentSize:  12
# minSize:  -1
# minV:  -1
# componentSize:  5
# minSize:  5
# minV:  5
# componentSize:  6
# minSize:  5
# minV:  5
# componentSize:  15
# minSize:  5
# minV:  5
# componentSize:  10
# minSize:  5
# minV:  5
# componentSize:  20
# minSize:  5
# minV:  5
# componentSize:  5
# minSize:  5
# minV:  31
# componentSize:  21
# minSize:  -1
# minV:  -1
# componentSize:  5
# minSize:  5
# minV:  5
# componentSize:  20
# minSize:  5
# minV:  5
# componentSize:  10
# minSize:  5
# minV:  5
# componentSize:  8
# minSize:  5
# minV:  5
# componentSize:  13
# minSize:  5
# minV:  5
# componentSize:  15
# minSize:  5
# minV:  5
# componentSize:  10
# minSize:  -1
# minV:  -1
# componentSize:  21
# minSize:  -1
# minV:  -1
# componentSize:  13
# minSize:  -1
# minV:  -1
# componentSize:  21
# minSize:  -1
# minV:  -1
# componentSize:  15
# minSize:  -1
# minV:  -1
# componentSize:  8
# minSize:  -1
# minV:  -1
